# %% [markdown]
# # 0.1 Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 0.2 Importing Dataframes

# %%
# Set filepath for IC Basket project
path = r'/Users/joefeuille/CF Analysis/Instacart Basket Analysis'

# %%
# Set Orders set as df_ords
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
# Set Products set as df_prods
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_time_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# # Mixed Data Types

# %%
# Create a data frame
df_test = pd.DataFrame()

# %%
# Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types

for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird]) > 0:
        print (col)
# Out:
# mix

# %%
# Reassigning "mix" column as a string variable
df_test['mix'] = df_test['mix'].astype('str')

# %% [markdown]
# # Missing Values

# %%
# Searching Products df for missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# Create new subset containing null values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
# Creating new df without null values
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# # Duplicates

# %%
# Creating a new subset containing only duplicate rows
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
# Checking for full duplicates
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# Create new df with no dups
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
# Renaming checked set as something that makes sense
df_prods_checked = df_prods_clean_no_dups

# %%
df_prods_checked.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # TASK 4.5

# %% [markdown]
# ## Q.1: If you haven’t performed the consistency checks covered in this Exercise on your df_prods dataframe, do so now.

# %%
### Done. Please see above.

# %% [markdown]
# ## Q.2: Run the df.describe() function on your df_prods dataframe. Using your new knowledge about how to interpret the output of this function, share in a markdown cell whether anything about the data looks off or should be investigated further.

# %%
# Checking original df first.
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
# Checking new df for comparison.
df_prods_checked.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      9.993282
# std    14340.705287     38.315784       5.850779    453.615536
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# ### Most of the values seem consistent, except that I suspect at least one outlier in the prices column. There's no way a grocery store carries something that's just shy of $100k.
# ### It might be worth checking the number of departments for any gaps, and the number of aisles too. A grocery store could have 134 aisles, but it's worth checking.

# %%
# Checking for prices column first.
df_prods_checked.sort_values('prices', ascending=False)
# Out:
#        product_id                      product_name  aisle_id  department_id  \
# 33666       33664             2 % Reduced Fat  Milk        84             16
# 21554       21553  Lowfat 2% Milkfat Cottage Cheese       108             16
# 19392       19391         Turkey Breast Tenderloins        49             12
# 25580       25579     Naturally Smoked Trout Fillet        15             12
# 40490       40486                   Chicken Tenders        49             12
# ...           ...                               ...       ...            ...
# 11307       11307                  Goat Cheese Logs         2             16
# 32805       32803                 Regular Deodorant        80             11
# 46627       46623                   Pie Pans, Large        10             17
# 37041       37037                       Redseedless        24              4
# 21464       21463      Vanilla Bean Light Ice Cream        37              1
#
#         prices
# 33666  99999.0
# ...

# %%
# Yep. Nobody's gonna pay that much for milk or cottage cheese.

# %%
# Checking for aisle_id column.
df_prods_checked.sort_values('aisle_id', ascending=False)
# Out:
#        product_id                                       product_name  \
# 45285       45281                                            Marsala
# 12825       12825                                            Sangria
# 6105         6105                                        Junmai Sake
# 22020       22019                                   Six Grapes Porto
# 2251         2251                                          Ruby Port
# ...           ...                                                ...
# 34239       34237             Organic Add Me Kale Blend Bagged Salad
# 4112         4112  Chopped Salad Bowl Italian Salad with Salami &...
# 41120       41116                                Spinach Dijon Salad
# 22854       22853                                  Pesto Pasta Salad
# 15767       15767                            Blackened Chicken Salad
#
#        aisle_id  department_id  prices
# 45285       134              5    10.8
# 12825       134              5     8.0
# ...

# %%
df_prods_aisles = df_prods_checked.sort_values('aisle_id', ascending=False)

# %%
df_prods_aisles.head(30)
# Out:
#        product_id                                product_name  aisle_id  \
# 45285       45281                                     Marsala       134
# 12825       12825                                     Sangria       134
# 6105         6105                                 Junmai Sake       134
# 22020       22019                            Six Grapes Porto       134
# 2251         2251                                   Ruby Port       134
# 44960       44956                                 Red Moscato       134
# 44875       44871                       Moscato Spumante Wine       134
# 30584       30582                           Natural Champagne       134
# 4285         4285          Sangria, Tradicional, Fresh Citrus       134
# 27908       27906                          Imperial Champagne       134
# 2216         2216                        California Champagne       134
# 39615       39611                      Blackberry Merlot Wine       134
# ...

# %% [markdown]
# ### I suspect the aisles column may actually be correct. But it is definitely worth revisiting those to pricing outliers.

# %% [markdown]
# # Q.3: Check for mixed-type data in your df_ords dataframe.

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_time_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
# Check for mixed types

for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird]) > 0:
        print (col)

# %% [markdown]
# #### Mix check returned nothing. Therefore, there were no columns with mixed types.

# %% [markdown]
# # Q.5: Run a check for missing values in your df_ords dataframe.

# %% [markdown]
# ##    In a markdown cell, report your findings and propose an explanation for any missing values you find.

# %%
# Searching Orders df for missing values
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_time_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# ### Days Since Prior Order has 206,209 missing values.

# %%
# Create new subset containing null values
df_nulls = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_nulls.head(20)
# Out:
#      Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 11           11   2168274        2    prior             1                   2
# 26           26   1374495        3    prior             1                   1
# 39           39   3343014        4    prior             1                   6
# 45           45   2717275        5    prior             1                   3
# 50           50   2086598        6    prior             1                   5
# 54           54   2565571        7    prior             1                   3
# 75           75    600894        8    prior             1                   6
# 79           79    280530        9    prior             1                   1
# 83           83   1224907       10    prior             1                   2
# 89           89   2411567       11    prior             1                   0
# ...

# %%
df_nulls.tail(20)
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 3420678     3420678   1955107   206190    prior             1
# 3420687     3420687    936117   206191    prior             1
# 3420693     3420693   3242108   206192    prior             1
# 3420708     3420708    313609   206193    prior             1
# 3420750     3420750   3395125   206194    prior             1
# 3420762     3420762    926652   206195    prior             1
# 3420782     3420782    825502   206196    prior             1
# 3420787     3420787   3325493   206197    prior             1
# 3420811     3420811   2154947   206198    prior             1
# 3420819     3420819   3302466   206199    prior             1
# 3420839     3420839   2508134   206200    prior             1
# 3420863     3420863     28210   206201    prior             1
# 3420896     3420896    799173   206202    prior             1
# 3420919     3420919   1991850   206203    prior             1
# ...

# %% [markdown]
# ### None of thise user_id numbers are repeating. This might suggest that the nulls values are associated with each user's first order.

# %% [markdown]
# # Q.6: Address the missing values using an appropriate method.

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_nulls.shape
# Out:
# (206209, 8)

# %%
#Adding a true/false column for First Time Orders
df_ords['first_time_ordering'] = np.where(df_ords['days_since_prior_order'].isnull(), True, False)

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_time_of_day  days_since_prior_order  first_time_ordering
# 0                  8                     NaN                 True
# 1                  7                    15.0                False
# 2                 12                    21.0                False
# 3                  7                    29.0                False
# 4                 15                    28.0                False

# %% [markdown]
# ### Added a new column for "First Time Ordering" to keep the sales data for further analysis.

# %% [markdown]
# # Q.7: Run a check for duplicate values in your df_ords data.

# %%
# Checking non-null order df for duplicates
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_week, order_time_of_day, days_since_prior_order, first_time_ordering]
# Index: []

# %% [markdown]
# ### No dups found in ords_clean

# %% [markdown]
# # Q.9: Export your final, cleaned df_prods and df_ords data as “.csv” files in your “Prepared Data” folder and give them appropriate, succinct names.

# %% [markdown]
# ### df_prods was exported earlier. Pleasee see above.

# %%
df_ords_clean = df_ords

# %%
# Exporting ords_clean as Orders Checked
df_ords_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'))
