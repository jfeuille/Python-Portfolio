# %% [markdown]
# # 0.1 Setup

# %% [markdown]
# # Q. 1 - Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Define path to project folders

path = r'/Users/joefeuille/CF Analysis/Instacart Basket Analysis'

# %%
# Setting exported df from Task 4.7 as file as ords_prods_merge

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ord_prod_mrg_derived.pkl'))

# %% [markdown]
# # Q.2 - For the entire dataframe, find the aggregated mean of the “order_number” column grouped by “department_id” for the df.

# %% [markdown]
# ### Checking df

# %%
ords_prods_merge.head()
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329.0      1.0    prior           1.0                 2.0
# 1  2398795.0      1.0    prior           2.0                 3.0
# 2   473747.0      1.0    prior           3.0                 3.0
# 3  2254736.0      1.0    prior           4.0                 4.0
# 4   431534.0      1.0    prior           5.0                 4.0
#
#    order_time_of_day  days_since_prior_order first_time_ordering  product_id  \
# 0                8.0                     NaN                True         196
# 1                7.0                    15.0               False         196
# 2               12.0                    21.0               False         196
# 3                7.0                    29.0               False         196
# 4               15.0                    28.0               False         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32435070, 20)

# %%
# Grouping df by department_id, and using agg to find the mean for order_number


ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %% [markdown]
# # Q.3 - Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# ### First of all, the mean has a greater range for the entire df than the subset. The department mean for the subset ranged from approximately 11 to 19, where the department mean for the entire df ranges from approximately 15 to 23.

# %% [markdown]
# ### Second, the mean values for individual departments has changed as well. For example, the mean value for dept 14 was 19.46 in the subset, but is 16.77 in the entire df. This demonstrates that the calculating the mean value in a subset may be a helpful place to get a feel for the data, but is no substitute for an analysis of the ENTIRE DATA SET.

# %% [markdown]
# ### Therefore, the only accurate mean value for each department are the values above, calculated from the entire dataframe.

# %% [markdown]
# # Q.4 - Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform( ) and loc( ) functions.

# %%
# Creating a max_order column for the entire df using transform

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking for new column

ords_prods_merge.head(15)
# Out:
#      order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329.0      1.0    prior           1.0                 2.0
# 1   2398795.0      1.0    prior           2.0                 3.0
# 2    473747.0      1.0    prior           3.0                 3.0
# 3   2254736.0      1.0    prior           4.0                 4.0
# 4    431534.0      1.0    prior           5.0                 4.0
# 5   3367565.0      1.0    prior           6.0                 2.0
# 6    550135.0      1.0    prior           7.0                 1.0
# 7   3108588.0      1.0    prior           8.0                 1.0
# 8   2295261.0      1.0    prior           9.0                 1.0
# 9   2550362.0      1.0    prior          10.0                 4.0
# 10  2968173.0     15.0    prior          15.0                 1.0
# 11  1870022.0     15.0    prior          17.0                 2.0
# 12  1911383.0     15.0    prior          18.0                 2.0
# ...

# %%
# Creating loyalty flag using loc

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking frequency of loyalty flag

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# NaN                       11
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # Q.5 - Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).

# %%
# Aggregating for Mean, Min, Max for product prices using loyalty flag

ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# # Q.6 - Create a spending flag for each user based on the average price across all their orders using the following criteria:

# %% [markdown]
# ## A: If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”

# %% [markdown]
# ## B: If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# First, creating new column for spending, using mean

ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329.0      1.0    prior           1.0                 2.0
# 1  2398795.0      1.0    prior           2.0                 3.0
# 2   473747.0      1.0    prior           3.0                 3.0
# 3  2254736.0      1.0    prior           4.0                 4.0
# 4   431534.0      1.0    prior           5.0                 4.0
#
#    order_time_of_day  days_since_prior_order first_time_ordering  product_id  \
# 0                8.0                     NaN                True         196
# 1                7.0                    15.0               False         196
# 2               12.0                    21.0               False         196
# 3                7.0                    29.0               False         196
# 4               15.0                    28.0               False         196
#
#    add_to_cart_order  ...  department_id prices  _merge    price_range_loc  \
# ...

# %%
# Second, using loc function to create flag for spending habits

ords_prods_merge.loc[ords_prods_merge['spending'] < 10, 'type_of_spender'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['spending'] >= 10, 'type_of_spender'] = 'High spender'

# %%
ords_prods_merge.head(15)
# Out:
#      order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329.0      1.0    prior           1.0                 2.0
# 1   2398795.0      1.0    prior           2.0                 3.0
# 2    473747.0      1.0    prior           3.0                 3.0
# 3   2254736.0      1.0    prior           4.0                 4.0
# 4    431534.0      1.0    prior           5.0                 4.0
# 5   3367565.0      1.0    prior           6.0                 2.0
# 6    550135.0      1.0    prior           7.0                 1.0
# 7   3108588.0      1.0    prior           8.0                 1.0
# 8   2295261.0      1.0    prior           9.0                 1.0
# 9   2550362.0      1.0    prior          10.0                 4.0
# 10  2968173.0     15.0    prior          15.0                 1.0
# 11  1870022.0     15.0    prior          17.0                 2.0
# 12  1911383.0     15.0    prior          18.0                 2.0
# ...

# %%
# Using a frequency check for type_of_spender

ords_prods_merge['type_of_spender'].value_counts(dropna = False)
# Out:
# Low spender     31800509
# High spender      634550
# NaN                   11
# Name: type_of_spender, dtype: int64

# %% [markdown]
# # Q.7 - Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. Use the following criteria:

# %% [markdown]
# ## A: If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”

# %% [markdown]
# ## B: If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”

# %% [markdown]
# ## C: If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# First, creating new column for order_freq, using median

ords_prods_merge['order_freq'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329.0      1.0    prior           1.0                 2.0
# 1  2398795.0      1.0    prior           2.0                 3.0
# 2   473747.0      1.0    prior           3.0                 3.0
# 3  2254736.0      1.0    prior           4.0                 4.0
# 4   431534.0      1.0    prior           5.0                 4.0
#
#    order_time_of_day  days_since_prior_order first_time_ordering  product_id  \
# 0                8.0                     NaN                True         196
# 1                7.0                    15.0               False         196
# 2               12.0                    21.0               False         196
# 3                7.0                    29.0               False         196
# 4               15.0                    28.0               False         196
#
#    add_to_cart_order  ...  _merge    price_range_loc     busiest_day  \
# ...

# %%
# Creating frequency flag using loc function

ords_prods_merge.loc[ords_prods_merge['order_freq'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['order_freq'] > 10) & (ords_prods_merge['order_freq'] <= 20), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['order_freq'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head()
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329.0      1.0    prior           1.0                 2.0
# 1  2398795.0      1.0    prior           2.0                 3.0
# 2   473747.0      1.0    prior           3.0                 3.0
# 3  2254736.0      1.0    prior           4.0                 4.0
# 4   431534.0      1.0    prior           5.0                 4.0
#
#    order_time_of_day  days_since_prior_order first_time_ordering  product_id  \
# 0                8.0                     NaN                True         196
# 1                7.0                    15.0               False         196
# 2               12.0                    21.0               False         196
# 3                7.0                    29.0               False         196
# 4               15.0                    28.0               False         196
#
#    add_to_cart_order  ...    price_range_loc     busiest_day    busiest_days  \
# ...

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21578273
# Regular customer          7217066
# Non-frequent customer     3639720
# NaN                            11
# Name: frequency_flag, dtype: int64

# %% [markdown]
# # Q.9 - Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Exporting ords_prods_merge df as "opm_aggr"

ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'opm_aggr.pkl'))
